# %% [markdown]
# <a href="https://colab.research.google.com/github/SebZurdo/MetNumUN2023II/blob/main/Certificados%20IBM/sescandon_cognitiveclassaapplieddatadciencewithpython.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Certificados IBM con Python - Extra Grades Métodos Numéricos 2023-2
#
# ### Sebastián Escandón Flórez

# %% [markdown]
# ## Python for data science

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Data Analysis with Python

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Data Visualization with Python

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Certificados en LinkedIn
#
# ### URL Perfil:
# https://www.linkedin.com/in/sescandon23/

# %% [markdown]
# ![image.png](data:image/png;base64,...)
